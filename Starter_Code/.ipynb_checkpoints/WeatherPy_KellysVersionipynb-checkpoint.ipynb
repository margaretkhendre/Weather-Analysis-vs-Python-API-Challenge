# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json 

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url ="http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat'] 
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | karratha
# Processing Record 3 of Set 1 | puerto escondido
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | kalomo
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | vallenar
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | aykhal
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | tumut
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | orocue
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | faya
# Processing Record 21 of Set 1 | mahibadhoo
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | iracoubo
# Processing Record 24 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 1 | saint-joseph
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | chunskiy
# Processing Record 31 of Set 1 | atasu
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | cochrane
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | quatre cocos
# Processing Record 36 of Set 1 | riyadh
# Processing Record 37 of Set 1 | beoumi
# Processing Record 38 of Set 1 | porbandar
# Processing Record 39 of Set 1 | gat
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | prince rupert
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | pakxan
# Processing Record 45 of Set 1 | sao lourenco do oeste
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | dikson
# Processing Record 48 of Set 1 | patnagarh
# Processing Record 49 of Set 1 | haines junction
# Processing Record 50 of Set 1 | susanville
# Processing Record 0 of Set 2 | gidam
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | yumen
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | bonavista
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | palmer
# Processing Record 11 of Set 2 | torbay
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | cefalu
# Processing Record 14 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 15 of Set 2 | kuito
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | vostok
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | havre-saint-pierre
# Processing Record 22 of Set 2 | vardo
# Processing Record 23 of Set 2 | sompeta
# Processing Record 24 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 2 | sibolga
# Processing Record 26 of Set 2 | erenhot
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | mount isa
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | gitarama
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | pizarro
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | coracao de jesus
# Processing Record 43 of Set 2 | beringovskiy
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | idritsa
# Processing Record 46 of Set 2 | ixtapa
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | lenggries
# Processing Record 0 of Set 3 | vaini
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | srednekolymsk
# Processing Record 5 of Set 3 | inongo
# Processing Record 6 of Set 3 | pandan
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | bucksport
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | mugur-aksy
# Processing Record 11 of Set 3 | urucara
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | bandarbeyla
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | berlevag
# Processing Record 17 of Set 3 | pithoragarh
# Processing Record 18 of Set 3 | flin flon
# Processing Record 19 of Set 3 | kavaratti
# Processing Record 20 of Set 3 | san policarpo
# Processing Record 21 of Set 3 | kieta
# Processing Record 22 of Set 3 | dingle
# Processing Record 23 of Set 3 | vila velha
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | carutapera
# Processing Record 26 of Set 3 | jieshi
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | leningradskiy
# Processing Record 29 of Set 3 | santa rosa de viterbo
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | chanika
# Processing Record 34 of Set 3 | middelkerke
# Processing Record 35 of Set 3 | deputatskiy
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | nioro
# Processing Record 38 of Set 3 | umm lajj
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | nyurba
# Processing Record 41 of Set 3 | avera
# Processing Record 42 of Set 3 | krasnogorskoye
# Processing Record 43 of Set 3 | tarko-sale
# Processing Record 44 of Set 3 | kropotkin
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | irbil
# Processing Record 48 of Set 3 | khasan
# Processing Record 49 of Set 3 | mataura
# Processing Record 0 of Set 4 | chauk
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | mar del plata
# Processing Record 3 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | nanchong
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | fria
# Processing Record 9 of Set 4 | santa rosalia
# Processing Record 10 of Set 4 | yessentuki
# Processing Record 11 of Set 4 | puerto ayora
# Processing Record 12 of Set 4 | castro
# Processing Record 13 of Set 4 | saint-francois
# Processing Record 14 of Set 4 | umba
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | half moon bay
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | troitsko-pechorsk
# Processing Record 20 of Set 4 | tual
# Processing Record 21 of Set 4 | kuusamo
# Processing Record 22 of Set 4 | watertown
# Processing Record 23 of Set 4 | sangar
# Processing Record 24 of Set 4 | abbeville
# Processing Record 25 of Set 4 | keti bandar
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | aras
# Processing Record 29 of Set 4 | hobyo
# Processing Record 30 of Set 4 | amapa
# Processing Record 31 of Set 4 | wilmington
# Processing Record 32 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 4 | urozhaynoye
# Processing Record 34 of Set 4 | san isidro
# Processing Record 35 of Set 4 | bubaque
# Processing Record 36 of Set 4 | gourcy
# Processing Record 37 of Set 4 | xiaoshi
# Processing Record 38 of Set 4 | saint george
# Processing Record 39 of Set 4 | puerto carreno
# Processing Record 40 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 41 of Set 4 | spas
# Processing Record 42 of Set 4 | mineiros
# Processing Record 43 of Set 4 | houma
# Processing Record 44 of Set 4 | kruisfontein
# Processing Record 45 of Set 4 | porto novo
# Processing Record 46 of Set 4 | sungaipenuh
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | tayu
# Processing Record 49 of Set 4 | gunjur
# Processing Record 0 of Set 5 | sarwar
# Processing Record 1 of Set 5 | arman
# Processing Record 2 of Set 5 | tambopata
# Processing Record 3 of Set 5 | merrill
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | barranca
# Processing Record 6 of Set 5 | atbasar
# Processing Record 7 of Set 5 | taltal
# Processing Record 8 of Set 5 | lagoa
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | pemagatsel
# Processing Record 11 of Set 5 | thompson
# Processing Record 12 of Set 5 | reyes
# Processing Record 13 of Set 5 | campana
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | basco
# Processing Record 16 of Set 5 | rongcheng
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | armidale
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | mao
# Processing Record 24 of Set 5 | bose
# Processing Record 25 of Set 5 | santa rosa
# Processing Record 26 of Set 5 | wenling
# Processing Record 27 of Set 5 | achacachi
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | bandhi
# Processing Record 30 of Set 5 | nantucket
# Processing Record 31 of Set 5 | san ignacio
# Processing Record 32 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 5 | san matias
# Processing Record 34 of Set 5 | macusani
# Processing Record 35 of Set 5 | uniao
# Processing Record 36 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 5 | new glasgow
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | planadas
# Processing Record 42 of Set 5 | ancud
# Processing Record 43 of Set 5 | nakhon thai
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | hambantota
# Processing Record 47 of Set 5 | venezuela
# Processing Record 48 of Set 5 | klaksvik
# Processing Record 49 of Set 5 | walvis bay
# Processing Record 0 of Set 6 | tias
# Processing Record 1 of Set 6 | road town
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | aklavik
# Processing Record 4 of Set 6 | bindura
# Processing Record 5 of Set 6 | altay
# Processing Record 6 of Set 6 | samarai
# Processing Record 7 of Set 6 | marrakesh
# Processing Record 8 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 6 | saint anthony
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | ailigandi
# Processing Record 12 of Set 6 | kutum
# Processing Record 13 of Set 6 | sao jose da coroa grande
# Processing Record 14 of Set 6 | kidal
# Processing Record 15 of Set 6 | brazzaville
# Processing Record 16 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 17 of Set 6 | sioux lookout
# Processing Record 18 of Set 6 | pueblo nuevo
# Processing Record 19 of Set 6 | dawlatabad
# Processing Record 20 of Set 6 | niono
# Processing Record 21 of Set 6 | kaitangata
# Processing Record 22 of Set 6 | belyy yar
# Processing Record 23 of Set 6 | suibara
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | port hardy
# Processing Record 26 of Set 6 | tautira
# Processing Record 27 of Set 6 | kichera
# Processing Record 28 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 6 | alice springs
# Processing Record 30 of Set 6 | panacan
# Processing Record 31 of Set 6 | richards bay
# Processing Record 32 of Set 6 | san jose
# Processing Record 33 of Set 6 | nurota
# Processing Record 34 of Set 6 | praia da vitoria
# Processing Record 35 of Set 6 | souillac
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | san ramon
# Processing Record 38 of Set 6 | stephenville crossing
# Processing Record 39 of Set 6 | marquette
# Processing Record 40 of Set 6 | nyandoma
# Processing Record 41 of Set 6 | imbituba
# Processing Record 42 of Set 6 | huainan
# Processing Record 43 of Set 6 | ziro
# Processing Record 44 of Set 6 | yar-sale
# Processing Record 45 of Set 6 | suntar
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | beitbridge
# Processing Record 48 of Set 6 | urman
# Processing Record 49 of Set 6 | ust-ishim
# Processing Record 0 of Set 7 | yerbogachen
# Processing Record 1 of Set 7 | aksarka
# Processing Record 2 of Set 7 | pisco
# Processing Record 3 of Set 7 | lerwick
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | sisimiut
# Processing Record 6 of Set 7 | nabire
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | conceicao do araguaia
# Processing Record 10 of Set 7 | chihuahua
# Processing Record 11 of Set 7 | itarema
# Processing Record 12 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 13 of Set 7 | chabahar
# Processing Record 14 of Set 7 | chinhoyi
# Processing Record 15 of Set 7 | kokopo
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | sao domingos
# Processing Record 18 of Set 7 | tiarei
# Processing Record 19 of Set 7 | pudem
# Processing Record 20 of Set 7 | upernavik
# Processing Record 21 of Set 7 | sabang
# Processing Record 22 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 7 | kaohsiung
# Processing Record 24 of Set 7 | sistranda
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | mahebourg
# Processing Record 27 of Set 7 | bemidji
# Processing Record 28 of Set 7 | huarmey
# Processing Record 29 of Set 7 | sorong
# Processing Record 30 of Set 7 | santa maria
# Processing Record 31 of Set 7 | stornoway
# Processing Record 32 of Set 7 | villa carlos paz
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | chapais
# Processing Record 35 of Set 7 | kirakira
# Processing Record 36 of Set 7 | ranau
# Processing Record 37 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 7 | masvingo
# Processing Record 39 of Set 7 | gamba
# Processing Record 40 of Set 7 | puerto madryn
# Processing Record 41 of Set 7 | nome
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 7 | rach gia
# Processing Record 46 of Set 7 | erie
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | deep river
# Processing Record 49 of Set 7 | bathsheba
# Processing Record 0 of Set 8 | banepa
# Processing Record 1 of Set 8 | qasigiannguit
# Processing Record 2 of Set 8 | seoul
# Processing Record 3 of Set 8 | charters towers
# Processing Record 4 of Set 8 | awbari
# Processing Record 5 of Set 8 | itubera
# Processing Record 6 of Set 8 | inirida
# Processing Record 7 of Set 8 | rundu
# Processing Record 8 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | san quintin
# Processing Record 11 of Set 8 | arlit
# Processing Record 12 of Set 8 | general roca
# Processing Record 13 of Set 8 | palaikastron
# Processing Record 14 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | farrukhnagar
# Processing Record 17 of Set 8 | cabra
# Processing Record 18 of Set 8 | poum
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | provideniya
# Processing Record 21 of Set 8 | saldanha
# Processing Record 22 of Set 8 | mabaruma
# Processing Record 23 of Set 8 | port-gentil
# Processing Record 24 of Set 8 | iranshahr
# Processing Record 25 of Set 8 | gornopravdinsk
# Processing Record 26 of Set 8 | lokosovo
# Processing Record 27 of Set 8 | linhares
# Processing Record 28 of Set 8 | alofi
# Processing Record 29 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 30 of Set 8 | goderich
# Processing Record 31 of Set 8 | kumluca
# Processing Record 32 of Set 8 | misratah
# Processing Record 33 of Set 8 | zhanakorgan
# Processing Record 34 of Set 8 | ahipara
# Processing Record 35 of Set 8 | talcahuano
# Processing Record 36 of Set 8 | taoudenni
# Processing Record 37 of Set 8 | baile herculane
# Processing Record 38 of Set 8 | luwuk
# Processing Record 39 of Set 8 | excelsior springs
# Processing Record 40 of Set 8 | portland
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | sulangan
# Processing Record 43 of Set 8 | olafsvik
# Processing Record 44 of Set 8 | chiang khong
# Processing Record 45 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 46 of Set 8 | point pedro
# Processing Record 47 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 48 of Set 8 | yulara
# Processing Record 49 of Set 8 | kankon
# Processing Record 0 of Set 9 | den helder
# Processing Record 1 of Set 9 | honningsvag
# Processing Record 2 of Set 9 | ilhabela
# Processing Record 3 of Set 9 | tourlaville
# Processing Record 4 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 9 | tshikapa
# Processing Record 6 of Set 9 | tessalit
# Processing Record 7 of Set 9 | vaitape
# Processing Record 8 of Set 9 | poopo
# Processing Record 9 of Set 9 | shelburne
# Processing Record 10 of Set 9 | dakar
# Processing Record 11 of Set 9 | ouesso
# Processing Record 12 of Set 9 | mopipi
# Processing Record 13 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 9 | susuman
# Processing Record 15 of Set 9 | huanuni
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | codrington
# Processing Record 18 of Set 9 | deniliquin
# Processing Record 19 of Set 9 | tura
# Processing Record 20 of Set 9 | katsuura
# Processing Record 21 of Set 9 | dalvik
# Processing Record 22 of Set 9 | sept-iles
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | billings
# Processing Record 25 of Set 9 | seka
# Processing Record 26 of Set 9 | xuddur
# Processing Record 27 of Set 9 | bratsk
# Processing Record 28 of Set 9 | altoona
# Processing Record 29 of Set 9 | hanna
# Processing Record 30 of Set 9 | fairbanks
# Processing Record 31 of Set 9 | port lincoln
# Processing Record 32 of Set 9 | terrace bay
# Processing Record 33 of Set 9 | sao filipe
# Processing Record 34 of Set 9 | nelson bay
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | sakaiminato
# Processing Record 37 of Set 9 | shingu
# Processing Record 38 of Set 9 | nishihara
# Processing Record 39 of Set 9 | canico
# Processing Record 40 of Set 9 | shakawe
# Processing Record 41 of Set 9 | belance
# Processing Record 42 of Set 9 | corinto
# Processing Record 43 of Set 9 | atambua
# Processing Record 44 of Set 9 | dinanagar
# Processing Record 45 of Set 9 | mumbwa
# Processing Record 46 of Set 9 | puerto asis
# Processing Record 47 of Set 9 | caxito
# Processing Record 48 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 49 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 0 of Set 10 | anloga
# Processing Record 1 of Set 10 | aksu
# Processing Record 2 of Set 10 | horadiz
# Processing Record 3 of Set 10 | tanga
# Processing Record 4 of Set 10 | homer
# Processing Record 5 of Set 10 | upata
# Processing Record 6 of Set 10 | opuwo
# Processing Record 7 of Set 10 | caravelas
# Processing Record 8 of Set 10 | waipawa
# Processing Record 9 of Set 10 | yen bai
# Processing Record 10 of Set 10 | berbera
# Processing Record 11 of Set 10 | vestmanna
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 13 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 14 of Set 10 | hasaki
# Processing Record 15 of Set 10 | burley
# Processing Record 16 of Set 10 | fairlie
# Processing Record 17 of Set 10 | sturgis
# Processing Record 18 of Set 10 | becerril
# Processing Record 19 of Set 10 | siwani
# City not found. Skipping...
# Processing Record 20 of Set 10 | naze
# Processing Record 21 of Set 10 | karasjok
# Processing Record 22 of Set 10 | oktyabrskiy
# Processing Record 23 of Set 10 | balkanabat
# Processing Record 24 of Set 10 | punta alta
# Processing Record 25 of Set 10 | hervey bay
# Processing Record 26 of Set 10 | atar
# Processing Record 27 of Set 10 | broome
# Processing Record 28 of Set 10 | komsomolets
# Processing Record 29 of Set 10 | egvekinot
# Processing Record 30 of Set 10 | san andres
# Processing Record 31 of Set 10 | bonthe
# Processing Record 32 of Set 10 | abu samrah
# Processing Record 33 of Set 10 | alyangula
# Processing Record 34 of Set 10 | costinesti
# Processing Record 35 of Set 10 | kloulklubed
# Processing Record 36 of Set 10 | saint-pierre
# Processing Record 37 of Set 10 | anito
# Processing Record 38 of Set 10 | zhetybay
# City not found. Skipping...
# Processing Record 39 of Set 10 | los llanos de aridane
# Processing Record 40 of Set 10 | oranjemund
# Processing Record 41 of Set 10 | fredericton
# Processing Record 42 of Set 10 | bukama
# Processing Record 43 of Set 10 | zonguldak
# Processing Record 44 of Set 10 | balsas
# Processing Record 45 of Set 10 | krasnokamensk
# Processing Record 46 of Set 10 | mahon
# Processing Record 47 of Set 10 | yamethin
# Processing Record 48 of Set 10 | cedar rapids
# Processing Record 49 of Set 10 | artesia
# Processing Record 0 of Set 11 | manokwari
# Processing Record 1 of Set 11 | bokovskaya
# Processing Record 2 of Set 11 | kedrovyy
# Processing Record 3 of Set 11 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 4 of Set 11 | inuvik
# Processing Record 5 of Set 11 | sretensk
# Processing Record 6 of Set 11 | koforidua
# Processing Record 7 of Set 11 | culpeper
# Processing Record 8 of Set 11 | ozernovskiy
# Processing Record 9 of Set 11 | belmonte
# Processing Record 10 of Set 11 | burgeo
# Processing Record 11 of Set 11 | port pirie
# Processing Record 12 of Set 11 | scarborough
# Processing Record 13 of Set 11 | kodinsk
# Processing Record 14 of Set 11 | effingham
# Processing Record 15 of Set 11 | hatsukaichi
# Processing Record 16 of Set 11 | rocha
# Processing Record 17 of Set 11 | yorosso
# Processing Record 18 of Set 11 | san gabriel
# Processing Record 19 of Set 11 | iquique
# Processing Record 20 of Set 11 | ugoofaaru
# Processing Record 21 of Set 11 | mandalgovi
# Processing Record 22 of Set 11 | pacific grove
# Processing Record 23 of Set 11 | abu kamal
# Processing Record 24 of Set 11 | tecpan
# Processing Record 25 of Set 11 | ayabe
# Processing Record 26 of Set 11 | okhotsk
# Processing Record 27 of Set 11 | severo-yeniseyskiy
# Processing Record 28 of Set 11 | kiruna
# Processing Record 29 of Set 11 | rupert
# Processing Record 30 of Set 11 | galesong
# Processing Record 31 of Set 11 | ambilobe
# Processing Record 32 of Set 11 | ust-tarka
# Processing Record 33 of Set 11 | winnemucca
# Processing Record 34 of Set 11 | maarianhamina
# Processing Record 35 of Set 11 | ivangorod
# Processing Record 36 of Set 11 | abnub
# Processing Record 37 of Set 11 | talnakh
# Processing Record 38 of Set 11 | ciudad bolivar
# Processing Record 39 of Set 11 | umea
# Processing Record 40 of Set 11 | logon
# Processing Record 41 of Set 11 | vila do maio
# Processing Record 42 of Set 11 | utevka
# Processing Record 43 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 11 | suhbaatar
# Processing Record 46 of Set 11 | van
# Processing Record 47 of Set 11 | santa fe
# Processing Record 48 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 11 | dawson creek
# Processing Record 0 of Set 12 | rio gallegos
# Processing Record 1 of Set 12 | pula
# Processing Record 2 of Set 12 | manzanillo
# Processing Record 3 of Set 12 | kyra
# Processing Record 4 of Set 12 | geelong
# Processing Record 5 of Set 12 | rio grande
# Processing Record 6 of Set 12 | pangody
# Processing Record 7 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 12 | mims
# Processing Record 9 of Set 12 | otjiwarongo
# Processing Record 10 of Set 12 | north bend
# Processing Record 11 of Set 12 | northam
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | litovko
# Processing Record 14 of Set 12 | tugulym
# Processing Record 15 of Set 12 | vestmannaeyjar
# Processing Record 16 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 12 | leh
# Processing Record 18 of Set 12 | koygorodok
# Processing Record 19 of Set 12 | dudinka
# Processing Record 20 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 12 | vagay
# Processing Record 22 of Set 12 | sri aman
# Processing Record 23 of Set 12 | garoua
# Processing Record 24 of Set 12 | boa vista
# Processing Record 25 of Set 12 | baherden
# Processing Record 26 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 12 | grand gaube
# Processing Record 28 of Set 12 | rosario
# Processing Record 29 of Set 12 | cleveland
# Processing Record 30 of Set 12 | causapscal
# Processing Record 31 of Set 12 | phan thiet
# Processing Record 32 of Set 12 | antsohihy
# Processing Record 33 of Set 12 | tadine
# Processing Record 34 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 12 | serenje
# Processing Record 36 of Set 12 | zalantun
# Processing Record 37 of Set 12 | krasnoarmeysk
# Processing Record 38 of Set 12 | ilulissat
# Processing Record 39 of Set 12 | starkville
# Processing Record 40 of Set 12 | todos santos
# Processing Record 41 of Set 12 | lucapa
# Processing Record 42 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 43 of Set 12 | asau
# Processing Record 44 of Set 12 | atherton
# Processing Record 45 of Set 12 | vila franca do campo
# Processing Record 46 of Set 12 | svetlogorsk
# Processing Record 47 of Set 12 | kuching
# Processing Record 48 of Set 12 | halifax
# Processing Record 49 of Set 12 | kaduqli
# Processing Record 0 of Set 13 | byron bay
# Processing Record 1 of Set 13 | schattdorf
# Processing Record 2 of Set 13 | yongan
# Processing Record 3 of Set 13 | shache
# Processing Record 4 of Set 13 | boueni
# Processing Record 5 of Set 13 | neuquen
# Processing Record 6 of Set 13 | padang
# Processing Record 7 of Set 13 | roma
# Processing Record 8 of Set 13 | trairi
# Processing Record 9 of Set 13 | caucasia
# Processing Record 10 of Set 13 | matay
# Processing Record 11 of Set 13 | hualmay
# Processing Record 12 of Set 13 | jiazi
# Processing Record 13 of Set 13 | voh
# Processing Record 14 of Set 13 | saravan
# Processing Record 15 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 13 | tabou
# Processing Record 17 of Set 13 | sakakah
# Processing Record 18 of Set 13 | laguna
# Processing Record 19 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 20 of Set 13 | adrar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            hobart -42.8794  147.3294     10.70        69          75
# 1          karratha -20.7377  116.8463     29.26        74          94
# 2  puerto escondido  15.8500  -97.0667     29.00        63         100
# 3           rikitea -23.1203 -134.9692     24.97        84         100
# 4          vallenar -28.5708  -70.7581     25.26        50           4
#
#    Wind Speed Country        Date
# 0        7.72      AU  1678225033
# 1        4.51      AU  1678225034
# 2        3.56      MX  1678224862
# 3       11.51      PF  1678225034
# 4        3.35      CL  1678225035

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  hobart -42.8794  147.3294     10.70        69          75
# 1                karratha -20.7377  116.8463     29.26        74          94
# 2        puerto escondido  15.8500  -97.0667     29.00        63         100
# 3                 rikitea -23.1203 -134.9692     24.97        84         100
# 4                vallenar -28.5708  -70.7581     25.26        50           4
#
#          Wind Speed Country        Date
# City_ID
# 0              7.72      AU  1678225033
# 1              4.51      AU  1678225034
# 2              3.56      MX  1678224862
# 3             11.51      PF  1678225034
# 4              3.35      CL  1678225035

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind= "scatter",x="Lat", y="Max Temp", grid= True, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")
plt.title("City Max Latitude vs Temperature (2022-10-18)")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind= "scatter",x="Lat", y="Humidity", grid= True, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (2022-10-18)")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind= "scatter",x="Lat", y="Cloudiness", grid= True, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (2022-10-18)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind= "scatter",x="Lat", y="Wind Speed", grid= True, edgecolors="black")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs Wind Speed (2022-10-18)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df.loc[city_data_df["Lat"]>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        puerto escondido  15.8500  -97.0667     29.00        63         100
# 5                   sitka  57.0531 -135.3300      4.94        36          20
# 8                  aykhal  66.0000  111.5000    -22.10        99         100
# 11             nikolskoye  59.7035   30.7861     -8.06        97          83
# 13                 barrow  71.2906 -156.7887     -5.99        93          75
#
#          Wind Speed Country        Date
# City_ID
# 2              3.56      MX  1678224862
# 5              0.00      US  1678225035
# 8              3.04      RU  1678225036
# 11             2.29      RU  1678224754
# 13             2.57      US  1678225037

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                hobart -42.8794  147.3294     10.70        69          75
# 1              karratha -20.7377  116.8463     29.26        74          94
# 3               rikitea -23.1203 -134.9692     24.97        84         100
# 4              vallenar -28.5708  -70.7581     25.26        50           4
# 6        saint-philippe -21.3585   55.7679     24.77        88          82
#
#          Wind Speed Country        Date
# City_ID
# 0              7.72      AU  1678225033
# 1              4.51      AU  1678225034
# 3             11.51      PF  1678225034
# 4              3.35      CL  1678225035
# 6              5.16      RE  1678225035

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
#Linear regression for Northern Hemisphere
xValues=northern_hemi_df["Lat"]
yValues= northern_hemi_df["Max Temp"]
slope, intercept, rvalue, pvalue, sterr= linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(0,-30), color= "red")

plt.ylabel("Max temp")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= -0.9017605651737711

# %%
# Linear regression on Southern Hemisphere
xValues=southern_hemi_df["Lat"]
yValues=southern_hemi_df["Max Temp"]
slope, intercept, rvalue, pvalue, sterr= linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(-50,30), color= "red")

plt.ylabel("Max temp")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= 0.3688920932131278

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, we see a negative linear relationship that tells us that as latitude increases, temperature decreases. The opposite occurs in the southern hemisphere. We see a positive relationship; as latitude increases, temperature also increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
xValues=northern_hemi_df["Lat"]
yValues= northern_hemi_df["Humidity"]
slope, intercept, rvalue, pvalue, sterr= linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(50,20), color= "red")

plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= 0.3475064761065775

# %%
# Southern Hemisphere
xValues=southern_hemi_df["Lat"]
yValues=southern_hemi_df["Humidity"]
slope, intercept, rvalue, pvalue, sterr= linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(-20,20), color= "red")
plt.title('Humidity vs Lat')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.show()
# Out:
# r-value= 0.4159958037243135

# %% [markdown]
# **Discussion about the linear relationship:** In both southern and northern hemispheres, we see a positive linear relationships; as latitude increases, humidity also increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
xValues=northern_hemi_df["Lat"]
yValues= northern_hemi_df["Cloudiness"]
slope, intercept, rvalue, pvalue, sterr= linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(10,30), color= "red")

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= 0.19344546827163486

# %%
# Southern Hemisphere
xValues=southern_hemi_df["Lat"]
yValues=southern_hemi_df["Cloudiness"]
slope, intercept, rvalue, pvalue, sterr= linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(-50,30), color= "red")

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= 0.20142316158738

# %% [markdown]
# **Discussion about the linear relationship:** In both southern and northern hemispheres, we see positive linear relationships; as as latitude increases, cloudiness also increases.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
xValues=northern_hemi_df["Lat"]
yValues= northern_hemi_df["Wind Speed"]
slope, intercept, rvalue, pvalue, sterr= linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(0,14), color= "red")

plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= 0.09470303067497378

# %%
# Southern Hemisphere
xValues=southern_hemi_df["Lat"]
yValues=southern_hemi_df["Wind Speed"]
slope, intercept, rvalue, pvalue, sterr= linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
print(f"r-value= {rvalue}")
y= slope * xValues + intercept
y_equation= f"y= {slope:.2f}x + {intercept:.2f}"
plt.scatter(xValues, yValues)
plt.plot(xValues, y, color="red")
plt.annotate(y_equation,(-50,10), color= "red")

plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.show()
# Out:
# r-value= -0.2829207847383242

# %% [markdown]
# **Discussion about the linear relationship:** In both southern and northern hemispheres, we see negative linear relationships; as latitude increases, wind speed decreases. The northern hemisphere does not see a change as strong as the southern hemisphere though.
